# %% [markdown]
# # Dihedral Angle Calculator

# %% [markdown]
# This notebook comprehends all the steps necessary to parse the inputs from the ProteiNet dataset (link), append physical_chemical descriptors from AAIndex and calculate it's dihedral angles and distogram (currently Ca, planning on expanding to Cbeta but need answers from ProteinNet's creator). This is a work in progress and much of what is present here will be changed within the next months. For instance this block only loads a single casp record. To execute it, follow the steps below.

# %% [markdown]
# #### Installation of Libraries
#
# The original docker for tensorflow2 doesnt comes with several libraries used throughout this note book. So, pip execution could be broken outside this conteiner and for different versions of the tensorflow dockers available.
# Eventhough this script could be run on whatever computer that has the requirements met (Tensorflow 2.1.0 CUDA), be careful when running outside a container, since I could not verify compatibility with other systems.
#
# **The conteiner version and name is:**
# - TFn2.1.0
# - tensorflow/tensorflow:latest-gpu-py3-jupyter
#
# **Note that some of the libraries used on imported modules may be different, all the needed libs are downloaded below and listed on GitHub.**
#
# ##### Image ran: tensorflow/tensorflow:1.15.0-gpu-py3-jupyter
# docker pull tensorflow/tensorflow:1.15.0-gpu-py3-jupyter
#
# To run the container, one could also make an alias, as so:
#
# alias docker_tf='docker run -v /LOCAL/VOLUME/:/tf/CONTAINER_VOLUME -p 8888:8888 --rm --runtime=nvidia -it --rm tensorflow/tensorflow:latest-gpu-py3-jupyter'

# %% [markdown]
# ### How to Run this notebook:
# 1. First of all, download one of the ProteiNet TXT Datasets (this notebook was tested using CASP7's 50 fining);
# 2. Make sure you have the following packages installed:
# >> - Python 3 <br>
# >> - Tensorflow <br>
# >> - Scikit Learn <br>
# >> - Matplotlib <br>
# >> - tqdm <br>
# >> - regex <br>
# >> (you can download docker and pull/run the above mentioned container) <br>
# 3. Execute the cells in sequence.
# >> 1. Observe cell description before running. Some of them load files produced on previous steps. So you can continue to explore stuff and skip some cells.

# %% [markdown]
# ### Global and Control Variables
# <br>
# The variables listed and declared here will be used to control the entire process. Each of these will be described using comments following the declaration. The parameters written here **are the defaults**. Don't change unless you know exactly what you are doing. For instance, changin _p_number_ could generate a buffer overflow on your computer, and you will end up being mad.

# %%
import subprocess
import sys
import os
from os import listdir
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# Function for installation of libraries via pip
def install_pkg(package):
    subprocess.call([sys.executable, "-m", "pip", "install", package])

pkgs = ['scikit-learn==0.20.0','tqdm','scipy','seaborn','regex','biopython']

for package in pkgs:
    try:
        import package
    except ImportError:
        print('Trying to install Package: {}'.format(package))
        install_pkg(package)

# Import sub-block
# Takes care of already installed libraries on the container
import tensorflow as tf
from tqdm import tqdm_notebook as tqdm
import numpy as np
from Utils import Utils as utils
# Out:
# Trying to install Package: scikit-learn==0.20.0
# Trying to install Package: tqdm
# Trying to install Package: scipy
# Trying to install Package: seaborn
# Trying to install Package: regex
# Trying to install Package: biopython

# %%
#current = os.getcwd()
#utils.scan_obj(current+'/obj/')

# %%
import datagen_v002 as data_prep_lib

# %% [markdown]
# Falta colocar os parâmetros bonitinhos e então eu já mando pra treinar na consuelo
# Falta pouco, carai!! pouco pra predizer distancia!!
#
# Depois de fazer isso, eu vou precisar implementar a rede do MiniFold, mas usando máscaras
# Pra isso, eu vou precisar implementar outro DataGenerator (cópia desse, mas só que receve distâncias, na real posso
#                                                           até implementar um modo pro DataGenerator) que implemente
# aquela função Threshold (mas antes eu preciso entender o que ela faz!! Estudar isso nométodo dos cara e ver tambem
#                         o prospr)
# E logo depois tentar o método do alphaFold, de predizer em chunks
# 23/04/2020

# %%
data_files = {'train':['/tf/fernando/storage/model1/Model1_pipeline/casp7/training_70','train_70'],
              'valid':['/tf/fernando/storage/model1/Model1_pipeline/casp7/validation','valid_test'],
               'test':['/tf/fernando/storage/model1/Model1_pipeline/casp7/testing','testing_data/']}

for k in data_files.keys():
    print('Preparing file * {} * | storing at * {} *'.format(data_files[k][0].partition('//')[-1],data_files[k][1]))
    data_prep = data_prep_lib.Data_Prep_Pipeline(input_file=data_files[k][0])
    data_prep.make_batch(1,folder_name=data_files[k][1])
# Out:
# Preparing file *  * | storing at * train_70 *
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 1 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 2 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 3 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 4 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 5 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 6 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 8 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 9 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 10 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 11 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 12 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 13 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 14 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 15 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 16 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 17 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 18 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 19 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 20 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 21 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 22 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 23 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 24 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 25 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 26 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 27 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 28 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 29 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 30 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 31 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 32 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 33 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 34 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 35 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 36 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 37 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 38 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 39 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 40 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 41 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 42 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 43 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 44 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 45 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 46 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 47 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 48 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 49 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 50 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 51 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 52 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 53 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 54 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 55 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 56 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 57 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 58 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 59 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 60 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 61 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 62 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 63 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 64 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 65 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 66 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 67 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 68 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 69 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 70 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 71 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 72 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 73 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 74 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 75 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 76 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 77 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 78 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 79 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 80 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 81 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 82 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 83 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 84 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 85 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 86 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 87 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 88 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 89 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 90 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 91 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 92 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 93 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 94 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 95 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 96 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 97 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 98 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 99 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 100 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 101 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 102 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 103 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 104 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 105 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 106 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 107 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 108 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 109 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 110 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 111 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 112 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 113 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 114 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 115 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 116 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 117 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 118 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 119 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 120 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 121 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 122 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 123 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 124 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 125 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 126 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 127 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 128 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 129 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 130 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 131 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 132 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 133 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 134 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 135 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 136 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 137 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 138 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 139 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 140 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 141 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 142 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 143 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 144 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 145 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 146 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 147 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 148 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 149 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 150 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 151 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 152 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 153 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 154 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 155 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 156 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 157 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 158 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 159 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 160 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 161 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 162 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 163 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 164 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 165 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 166 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 167 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 168 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 169 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 170 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 171 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 172 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 173 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 174 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 175 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 176 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 177 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 178 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 179 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 180 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 181 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 182 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 183 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 184 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 185 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 186 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 187 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 188 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 189 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 190 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 191 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 192 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 193 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 194 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 195 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 196 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 197 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 198 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 199 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 200 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 201 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 202 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 203 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 204 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 205 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 206 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 207 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 208 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 209 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 210 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 211 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 212 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 213 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 214 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 215 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 216 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 217 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 218 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 219 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 220 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 221 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 222 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 223 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 224 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 225 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 226 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 227 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 228 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 229 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 230 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 231 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 232 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 233 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 234 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 235 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 236 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 237 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 238 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 239 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 240 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 241 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 242 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 243 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 244 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 245 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 246 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 247 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 248 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 249 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 250 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 251 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 252 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 253 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 254 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 255 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 256 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 257 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 258 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 259 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 260 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 261 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 262 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 263 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 264 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 265 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 266 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 267 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 268 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 269 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 270 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 271 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 272 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 273 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 274 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 275 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 276 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 277 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 278 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 279 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 280 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 281 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 282 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 283 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 284 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 285 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 286 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 287 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 288 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 289 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 290 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 291 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 292 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 293 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 294 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 295 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 296 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 297 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 298 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 299 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 300 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 301 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 302 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 303 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 304 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 305 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 306 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 307 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 308 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 309 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 310 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 311 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 312 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 313 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 314 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 315 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 316 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 317 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 318 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 319 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 320 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 321 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 322 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 323 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 324 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 325 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 326 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 327 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 328 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 329 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 330 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 331 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 332 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 333 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 334 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 335 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 336 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 337 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 338 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 339 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 340 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 341 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 342 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 343 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 344 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 345 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 346 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 347 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 348 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 349 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 350 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 351 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 352 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 353 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 354 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 355 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 356 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 357 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 358 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 359 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 360 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 361 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 362 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 363 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 364 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 365 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 366 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 367 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 368 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 369 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 370 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 371 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 372 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 373 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 374 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 375 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 376 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 377 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 378 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 379 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 380 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 381 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 382 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 383 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 384 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 385 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 386 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 387 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 388 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 389 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 390 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 391 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 392 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 393 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 394 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 395 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 396 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 397 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 398 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 399 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 400 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 401 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 402 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 403 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 404 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 405 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 406 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 407 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 408 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 409 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 410 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 411 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 412 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 413 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 414 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 415 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 416 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 417 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 418 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 419 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 420 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 421 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 422 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 423 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 424 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 425 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 426 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 427 with 1 entries', max=1.0, style=Prog…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 428 with 1 entries', max=1.0, style=Prog…
# ...
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7252 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7253 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7254 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7255 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7256 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7257 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7258 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7259 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7260 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7261 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7262 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7263 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7264 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7265 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7266 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7267 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7268 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7269 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7270 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7271 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7272 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7273 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7274 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7275 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7276 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7277 with 1 entries', max=1.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7278 with 1 entries', max=1.0, style=Pro…
# Finished loading everything
# Preparing file *  * | storing at * valid_test *
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 1 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 2 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 3 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 4 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 5 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 6 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 8 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 9 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 10 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 11 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 12 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 13 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 14 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 15 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 16 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 17 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 18 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 19 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 20 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 21 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 22 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 23 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 24 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 25 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 26 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 27 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 28 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 29 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 30 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 31 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 32 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 33 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 34 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 35 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 36 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 37 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 38 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 39 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 40 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 41 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 42 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 43 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 44 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 45 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 46 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 47 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 48 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 49 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 50 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 51 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 52 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 53 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 54 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 55 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 56 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 57 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 58 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 59 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 60 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 61 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 62 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 63 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 64 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 65 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 66 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 67 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 68 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 69 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 70 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 71 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 72 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 73 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 74 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 75 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 76 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 77 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 78 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 79 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 80 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 81 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 82 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 83 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 84 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 85 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 86 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 87 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 88 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 89 with 1 entries', max=1.0, style=Progr…
# Finished loading everything
# Preparing file *  * | storing at * testing_data/ *
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 1 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 2 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 3 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 4 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 5 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 6 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 7 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 8 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 9 with 1 entries', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 10 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 11 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 12 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 13 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 14 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 15 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 16 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 17 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 18 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 19 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 20 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 21 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 22 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 23 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 24 with 1 entries', max=1.0, style=Progr…
# HBox(children=(FloatProgress(value=0.0, description='Processing batch 25 with 1 entries', max=1.0, style=Progr…
# Finished loading everything

# %%
data_prep = data_prep_lib.Data_Prep_Pipeline(input_file='/tf/fernando/storage/model1/Model1_pipeline/casp7/training_70')

# %%
#data_prep.open_dataset_file('/tf/fernando/storage/casp7_txt/training_50')

# %%
#data_prep.input_data_file

# %%
data_prep.make_batch(1,folder_name='train_70')
